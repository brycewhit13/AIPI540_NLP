# %%
# Imports
import pandas as pd

# %%
data = pd.read_csv('../data/book_data.tsv', sep='\t')
data
# Out:
#                                    title  \
# 0                                  Spare
# 1   Tomorrow, and Tomorrow, and Tomorrow
# 2                   Lessons in Chemistry
# 3                       Demon Copperhead
# 4                   I'm Glad My Mom Died
# 5                     Our Missing Hearts
# 6                        It Ends With Us
# 7                 A World of Curiosities
# 8            Remarkably Bright Creatures
# 9          I Have Some Questions for You
# 10                             Mad Honey
#
#                                   author  rating  num_ratings  \
# 0   Harry, Prince, Duke of Sussex, 1984-    3.70          300
# 1                       Zevin, Gabrielle    4.30          479
# 2                         Garmus, Bonnie    4.35         1234
# 3                    Kingsolver, Barbara    4.25          294
# 4               McCurdy, Jennette, 1992-    4.50          745
# 5                            Ng, Celeste    3.90          410
# ...

# %%
data.dtypes
# Out:
# title           object
# author          object
# rating         float64
# num_ratings      int64
# description     object
# url             object
# dtype: object
