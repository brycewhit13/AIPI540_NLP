# %%
# %pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.11.2-py3-none-any.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4-py3-none-any.whl (37 kB)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=9a0a31539504e1602156ff52d868c55c8dd51a86745154b62f33ecf10653e300
#   Stored in directory: /Users/iqraimtiaz/Library/Caches/pip/wheels/77/8a/04/7b1a8ce5de6555a18e09370d3d4fde48be9571ac07a623071e
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.11.2 bs4-0.0.1 soupsieve-2.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
books = pd.read_csv('/Users/iqraimtiaz/Documents/duke/Courses/540-DL/AIPI540_NLP/data/duke_books.csv')
books
# Out:
#                                                   Title  \
# 0     1998 vital statistics of the United States : v...
# 1     Cross into the blue-- practice your profession...
# 2     100 soruda Çanakkale muharebeleri - Duke Univ...
# 3     10개월, 종말이 오다 종말문학 공모전 신체강탈자 문학 공모전 수상작품집 - Duk...
# 4     12th Education and Training in Optics and Phot...
# ...                                                 ...
# 9995  2022 the 5th International Conference on Image...
# 9996  2022 the 5th International Conference on Infor...
# 9997  2022 the 5th International Conference on Machi...
# 9998  2022 the 5th International Conference on Robot...
# 9999  2022 The 5th International Conference on Softw...
#
#                            Location  \
# 0     Perkins Public Documents/Maps
# 1     Perkins Public Documents/Maps
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 9995                            NaN
# 9996                            NaN
# 9997                            NaN
# 9998                            NaN
# 9999                            NaN
#
#                                            Authors  \
# 0     National Center for Health Statistics (U.S.)
# 1         United States. Air Force Medical Service
# 2                                Kurşun, Zekeriya
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 9995                                           NaN
# 9996                                           NaN
# 9997                                           NaN
# 9998                                           NaN
# 9999                                           NaN
#
#                                                 Summary  \
# 0     This CD ROM contains chiefly tables, a guide t...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Proceedings of SPIE present the original resea...
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#                                               Published Language  \
# 0     [Washington, D.C.?] : Dept. of Health and Huma...  English
# 1     [Washington, D.C.?] : U.S. Air Force, Medical ...  English
# 2     Istanbul: Kültür ve Turizm Bakanlığı Yayınl...  Turkish
# 3                                             황금가지 2012   Korean
# 4                                [S.l.] : [s.n.], 9999.      NaN
# ...                                                 ...      ...
# 9995  [Place of publication not identified] : Associ...      NaN
# 9996  [Place of publication not identified] : Associ...      NaN
# 9997  [Place of publication not identified] : Associ...      NaN
# 9998  [Place of publication not identified] : Associ...      NaN
# 9999  [Place of publication not identified] : Associ...      NaN
#
#                                          System Details  \
# 0     System requirements for Windows: IBM-compatibl...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#                                                   Notes  \
# 0     Title from title screen.ISO 9660 format."Shipp...
# 1                       Shipping list no.: 2002-0298-P.
# 2                                                   NaN
# 3                                                   NaN
# 4                          Title from content provider.
# ...                                                 ...
# 9995                       Title from content provider.
# 9996                       Title from content provider.
# 9997                       Title from content provider.
# 9998                       Title from content provider.
# 9999                       Title from content provider.
#
#                                           Description  \
# 0                                1 CD-ROM ; 4 3/4 in.
# 1     1 folded sheet (6 p.) : col. ill. ; 22 x 10 cm.
# 2                                              190 p.
# 3                                                 NaN
# 4                                   1 online resource
# ...                                               ...
# 9995                                1 online resource
# 9996                                1 online resource
# 9997                                1 online resource
# 9998                                1 online resource
# 9999                                1 online resource
#
#                                     Description Details  \
# 0     Dimensions: 4 3/4 in.Color characteristics: po...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#                         Genre         OCLC      Other Identifiers  System ID
# 0     TablesStatistics, Vital   49537646.0  GPO Item Number: 0510  003072700
# 1                         NaN   50729109.0  GPO Item Number: 0424  003111128
# 2                         NaN          NaN                    NaN  010763713
# 3                         NaN  841187472.0                    NaN  010791862
# 4            Electronic books          NaN                    NaN  008891635
# ...                       ...          ...                    ...        ...
# 9995         Electronic books          NaN                    NaN  010407751
# 9996                      NaN          NaN                    NaN  010742130
# 9997         Electronic books          NaN                    NaN  010489000
# 9998                      NaN          NaN                    NaN  010742131
# 9999         Electronic books          NaN                    NaN  010476020
#
# [10000 rows x 14 columns]

# %%
# check how many nans are in summary
books['Summary'].isna().sum()
# create a new column for keyword matching as True or False and update in each iteration
books['Keyword Match'] = False
# update this column in each iteration
books.loc[books['Summary'].str.contains('machine learning', case=False), 'Keyword Match'] = True
# Out:
# 3217

# %%
import sys
sys.path.append("../")


from scripts import prompt_matching as pm
prompt_matching = pm.PromptMatching()
#prompt = "Find a book about a detective solving a murder mystery in a small town."
prompt = "Looking for a book that explores the changing role of religion in the 20th century. Specifically, how certain religious groups redefined what it meant to be religious and allowed their members the choice of what kind of God to believe in, or the option to not believe in God at all."

prompt_matching.keyword_matching(prompt,books)
prompt_matching.cosine_similarity(prompt,books)

# check if cosine similarity is > 0.6 or keywords_match is true
matched = books[(books['cosine_similarity']>0.75) | (books['keywords_match'])]
matched
# Out:
#                                                   Title Location  \
# 4010  Critical Legal Education As a Subversive Activ...      NaN
# 5000  God-optional religion in twentieth-century Ame...      NaN
# 6977  The pursuit of dominance : 2000 years of super...      NaN
#
#                        Authors  \
# 4010               Duffy, Mark
# 5000         May, Isaac Barnes
# 6977  Fettweis, Christopher J.
#
#                                                 Summary  \
# 4010  In an age when everyone aspires to teach criti...
# 5000  By the beginning of the twentieth century, it ...
# 6977  A sweeping yet concise account of history's em...
#
#                                               Published Language  \
# 4010  [Place of publication not identified] : Taylor...      NaN
# 5000  New York, NY, United States of America : Oxfor...  English
# 6977     New York, NY : Oxford University Press, [2023]  English
#
#      System Details                                              Notes  \
# 4010            NaN                       Title from content provider.
# 5000            NaN  Description based on print version record.Incl...
# 6977            NaN  Description based on print version record.Incl...
#
#                        Description   Description Details         Genre  OCLC  \
# 4010             1 online resource                   NaN           NaN   NaN
# 5000  1 online resource (pages cm)  File type: text file           NaN   NaN
# 6977  1 online resource (pages cm)  File type: text file  Case studies   NaN
#
#      Other Identifiers  System ID  keywords_match  cosine_similarity
# 4010               NaN  010762071           False           0.759239
# 5000  LCCN: 2022027499  010759819           False           0.879091
# 6977  LCCN: 2022027377  010760558           False           0.751634

# %%
matched.Title
# Out:
# 4010    Critical Legal Education As a Subversive Activ...
# 5000    God-optional religion in twentieth-century Ame...
# 6977    The pursuit of dominance : 2000 years of super...
# Name: Title, dtype: object
